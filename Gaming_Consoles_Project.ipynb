# %% [markdown]
# <a href="https://colab.research.google.com/github/hailt1992/Data_projects_TripleTen/blob/main/Gaming_Consoles_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Scenario**
# A local shop buys, repairs, and sells discontinued electronics. One of their biggest earners is old gaming consoles. The shop has collected historical sales data about these discontinued consoles in order to set prices and help prioritize which ones to repair. Let's take a look at the dataset:

# %% [markdown]
# This table contains six columns:
#
# **console** — the type of gaming console
#
# **company**— the company that manufactured it
#
# **release_year** — the year it was first introduced to the market
#
# **discontinued_year** — the year the company stopped manufacturing it
#
# **release_price** — the cost of the console at its release
#
# **units_sold** — the number of consoles sold over its product run
# This dataset presents a great opportunity to practice working with complex lists in Python while analyzing the relative success of these old gaming consoles.

# %% [markdown]
# `1. Printing the data to the screen in a nice-looking table format.`

# %%
console_data = [['NES', 'Nintendo', 1985, 1995, 179.0, 61910000],
 ['Game Boy', 'Nintendo', 1989, 2003, 89.99, 118690000],
 ['SNES', 'Nintendo', 1990, 2003, 199.0, 49100000],
 ['Virtual Boy', 'Nintendo', 1995, 1996, 179.95, 770000],
 ['Game Boy Advance', 'Nintendo', 2001, 2010, 99.99, 81510000],
 ['Atari 2600', 'Atari', 1977, 1992, 199.0, 30000000],
 ['Sega Genesis', 'Sega', 1988, 1997, 189.0, 30750000],
 ['Game Gear', 'Sega', 1990, 1997, 149.99, 10620000],
 ['Sega CD', 'Sega', 1991, 1996, 299.0, 2240000],
 ['3DO', 'The 3DO Company', 1993, 1996, 699.99, 2000000],
 ['PlayStation', 'Sony Electronics', 1994, 2006, 299.0, 102490000],
 ['PlayStation 2', 'Sony Electronics', 2000, 2013, 299.0, 155000000]]

for i in console_data:
  for r in i:
    print(f'{r:<20}', end = "")
  print()
# Out:
# NES                 Nintendo            1985                1995                179.0               61910000
# Game Boy            Nintendo            1989                2003                89.99               118690000
# SNES                Nintendo            1990                2003                199.0               49100000
# Virtual Boy         Nintendo            1995                1996                179.95              770000
# Game Boy Advance    Nintendo            2001                2010                99.99               81510000
# Atari 2600          Atari               1977                1992                199.0               30000000
# Sega Genesis        Sega                1988                1997                189.0               30750000
# Game Gear           Sega                1990                1997                149.99              10620000
# Sega CD             Sega                1991                1996                299.0               2240000
# 3DO                 The 3DO Company     1993                1996                699.99              2000000
# PlayStation         Sony Electronics    1994                2006                299.0               102490000
# PlayStation 2       Sony Electronics    2000                2013                299.0               155000000

# %% [markdown]
# `2. Loop over each row in console_data and calculate the lifespan in years using the released year and discontinued year columns.`

# %%
from tabulate import tabulate

console_data = [['NES', 'Nintendo', 1985, 1995, 179.0, 61910000],
 ['Game Boy', 'Nintendo', 1989, 2003, 89.99, 118690000],
 ['SNES', 'Nintendo', 1990, 2003, 199.0, 49100000],
 ['Virtual Boy', 'Nintendo', 1995, 1996, 179.95, 770000],
 ['Game Boy Advance', 'Nintendo', 2001, 2010, 99.99, 81510000],
 ['Atari 2600', 'Atari', 1977, 1992, 199.0, 30000000],
 ['Sega Genesis', 'Sega', 1988, 1997, 189.0, 30750000],
 ['Game Gear', 'Sega', 1990, 1997, 149.99, 10620000],
 ['Sega CD', 'Sega', 1991, 1996, 299.0, 2240000],
 ['3DO', 'The 3DO Company', 1993, 1996, 699.99, 2000000],
 ['PlayStation', 'Sony Electronics', 1994, 2006, 299.0, 102490000],
 ['PlayStation 2', 'Sony Electronics', 2000, 2013, 299.0, 155000000]]

for i in console_data:
  lifespan = i.append(i[-3] - i[-4])

print(tabulate(console_data, tablefmt="grid"))
# Out:
# +------------------+------------------+------+------+--------+-----------+----+
# | NES              | Nintendo         | 1985 | 1995 | 179    |  61910000 | 10 |
# +------------------+------------------+------+------+--------+-----------+----+
# | Game Boy         | Nintendo         | 1989 | 2003 |  89.99 | 118690000 | 14 |
# +------------------+------------------+------+------+--------+-----------+----+
# | SNES             | Nintendo         | 1990 | 2003 | 199    |  49100000 | 13 |
# +------------------+------------------+------+------+--------+-----------+----+
# | Virtual Boy      | Nintendo         | 1995 | 1996 | 179.95 |    770000 |  1 |
# +------------------+------------------+------+------+--------+-----------+----+
# | Game Boy Advance | Nintendo         | 2001 | 2010 |  99.99 |  81510000 |  9 |
# +------------------+------------------+------+------+--------+-----------+----+
# | Atari 2600       | Atari            | 1977 | 1992 | 199    |  30000000 | 15 |
# +------------------+------------------+------+------+--------+-----------+----+
# | Sega Genesis     | Sega             | 1988 | 1997 | 189    |  30750000 |  9 |
# +------------------+------------------+------+------+--------+-----------+----+
# | Game Gear        | Sega             | 1990 | 1997 | 149.99 |  10620000 |  7 |
# +------------------+------------------+------+------+--------+-----------+----+
# | Sega CD          | Sega             | 1991 | 1996 | 299    |   2240000 |  5 |
# +------------------+------------------+------+------+--------+-----------+----+
# | 3DO              | The 3DO Company  | 1993 | 1996 | 699.99 |   2000000 |  3 |
# +------------------+------------------+------+------+--------+-----------+----+
# | PlayStation      | Sony Electronics | 1994 | 2006 | 299    | 102490000 | 12 |
# +------------------+------------------+------+------+--------+-----------+----+
# | PlayStation 2    | Sony Electronics | 2000 | 2013 | 299    | 155000000 | 13 |
# +------------------+------------------+------+------+--------+-----------+----+

# %% [markdown]
# `The code to create the lifespan column from the last task is provided for you here in the precode, as is the code to print your result. Add a line of code to sort console_data by the new lifespan column in order from longest to shortest, and save the result in a variable called sorted_lifespan_data.`

# %%
console_data = [['NES', 'Nintendo', 1985, 1995, 179.0, 61910000],
 ['Game Boy', 'Nintendo', 1989, 2003, 89.99, 118690000],
 ['SNES', 'Nintendo', 1990, 2003, 199.0, 49100000],
 ['Virtual Boy', 'Nintendo', 1995, 1996, 179.95, 770000],
 ['Game Boy Advance', 'Nintendo', 2001, 2010, 99.99, 81510000],
 ['Atari 2600', 'Atari', 1977, 1992, 199.0, 30000000],
 ['Sega Genesis', 'Sega', 1988, 1997, 189.0, 30750000],
 ['Game Gear', 'Sega', 1990, 1997, 149.99, 10620000],
 ['Sega CD', 'Sega', 1991, 1996, 299.0, 2240000],
 ['3DO', 'The 3DO Company', 1993, 1996, 699.99, 2000000],
 ['PlayStation', 'Sony Electronics', 1994, 2006, 299.0, 102490000],
 ['PlayStation 2', 'Sony Electronics', 2000, 2013, 299.0, 155000000]]

for row in console_data:
    lifespan = row[3] - row[2]
    row.append(lifespan)

def key(row):
    return row[-1]

sorted_lifespan_data = sorted(console_data, key = key, reverse=True)

for row in sorted_lifespan_data:
    for elem in row:
        print(f'{elem:<20}', end='')
    print()
# Out:
# Atari 2600          Atari               1977                1992                199.0               30000000            15
# Game Boy            Nintendo            1989                2003                89.99               118690000           14
# SNES                Nintendo            1990                2003                199.0               49100000            13
# PlayStation 2       Sony Electronics    2000                2013                299.0               155000000           13
# PlayStation         Sony Electronics    1994                2006                299.0               102490000           12
# NES                 Nintendo            1985                1995                179.0               61910000            10
# Game Boy Advance    Nintendo            2001                2010                99.99               81510000            9
# Sega Genesis        Sega                1988                1997                189.0               30750000            9
# Game Gear           Sega                1990                1997                149.99              10620000            7
# Sega CD             Sega                1991                1996                299.0               2240000             5
# 3DO                 The 3DO Company     1993                1996                699.99              2000000             3
# Virtual Boy         Nintendo            1995                1996                179.95              770000              1

# %% [markdown]
# `Calculate a new metric, total revenue, which we will estimate as the product of release price and the total number of units sold (the last two values in each row). Use a for loop over the rows of console_data to calculate the total revenue and append the result to the end of each row.`

# %%
console_data = [['NES', 'Nintendo', 1985, 1995, 179.0, 61910000],
 ['Game Boy', 'Nintendo', 1989, 2003, 89.99, 118690000],
 ['SNES', 'Nintendo', 1990, 2003, 199.0, 49100000],
 ['Virtual Boy', 'Nintendo', 1995, 1996, 179.95, 770000],
 ['Game Boy Advance', 'Nintendo', 2001, 2010, 99.99, 81510000],
 ['Atari 2600', 'Atari', 1977, 1992, 199.0, 30000000],
 ['Sega Genesis', 'Sega', 1988, 1997, 189.0, 30750000],
 ['Game Gear', 'Sega', 1990, 1997, 149.99, 10620000],
 ['Sega CD', 'Sega', 1991, 1996, 299.0, 2240000],
 ['3DO', 'The 3DO Company', 1993, 1996, 699.99, 2000000],
 ['PlayStation', 'Sony Electronics', 1994, 2006, 299.0, 102490000],
 ['PlayStation 2', 'Sony Electronics', 2000, 2013, 299.0, 155000000]]

for i in console_data:
   i.append(i[-1] * i[-2])

sorted_revenue_data = sorted(console_data, key=lambda row: row[-1], reverse=True)

for row in sorted_revenue_data:
    for elem in row:
        print(f'{elem:<20}', end='')
    print()
# Out:
# PlayStation 2       Sony Electronics    2000                2013                299.0               155000000           46345000000.0
# PlayStation         Sony Electronics    1994                2006                299.0               102490000           30644510000.0
# NES                 Nintendo            1985                1995                179.0               61910000            11081890000.0
# Game Boy            Nintendo            1989                2003                89.99               118690000           10680913100.0
# SNES                Nintendo            1990                2003                199.0               49100000            9770900000.0
# Game Boy Advance    Nintendo            2001                2010                99.99               81510000            8150184900.0
# Atari 2600          Atari               1977                1992                199.0               30000000            5970000000.0
# Sega Genesis        Sega                1988                1997                189.0               30750000            5811750000.0
# Game Gear           Sega                1990                1997                149.99              10620000            1592893800.0
# 3DO                 The 3DO Company     1993                1996                699.99              2000000             1399980000.0
# Sega CD             Sega                1991                1996                299.0               2240000             669760000.0
# Virtual Boy         Nintendo            1995                1996                179.95              770000              138561500.0

# %% [markdown]
# `Use a for loop to print the first column of the table — the names of the consoles.`

# %%
console_data = [['NES', 'Nintendo', 1985, 1995, 179.0, 61910000],
 ['Game Boy', 'Nintendo', 1989, 2003, 89.99, 118690000],
 ['SNES', 'Nintendo', 1990, 2003, 199.0, 49100000],
 ['Virtual Boy', 'Nintendo', 1995, 1996, 179.95, 770000],
 ['Game Boy Advance', 'Nintendo', 2001, 2010, 99.99, 81510000],
 ['Atari 2600', 'Atari', 1977, 1992, 199.0, 30000000],
 ['Sega Genesis', 'Sega', 1988, 1997, 189.0, 30750000],
 ['Game Gear', 'Sega', 1990, 1997, 149.99, 10620000],
 ['Sega CD', 'Sega', 1991, 1996, 299.0, 2240000],
 ['3DO', 'The 3DO Company', 1993, 1996, 699.99, 2000000],
 ['PlayStation', 'Sony Electronics', 1994, 2006, 299.0, 102490000],
 ['PlayStation 2', 'Sony Electronics', 2000, 2013, 299.0, 155000000]]

for name in console_data:
    print(f' The name of the consoles is {name[0]}')
# Out:
#  The name of the consoles is NES
#  The name of the consoles is Game Boy
#  The name of the consoles is SNES
#  The name of the consoles is Virtual Boy
#  The name of the consoles is Game Boy Advance
#  The name of the consoles is Atari 2600
#  The name of the consoles is Sega Genesis
#  The name of the consoles is Game Gear
#  The name of the consoles is Sega CD
#  The name of the consoles is 3DO
#  The name of the consoles is PlayStation
#  The name of the consoles is PlayStation 2
